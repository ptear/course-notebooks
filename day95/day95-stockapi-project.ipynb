# %%
import pandas as pd
import plotly.express as px

# %%
data = pd.read_csv("aapl_daily.csv", index_col=0, parse_dates=True)

# %%
data.head()
# Out:
#                            adj_close
# date
# 2020-12-08 00:00:00+00:00     124.38
# 2020-12-09 00:00:00+00:00     121.78
# 2020-12-10 00:00:00+00:00     123.24
# 2020-12-11 00:00:00+00:00     122.41
# 2020-12-14 00:00:00+00:00     121.78

# %%
fig = px.line(data, x=data.index, y="adj_close", title='AAPL last 100 days')
fig.show()
# Out:
# <div>                            <div id="935e6661-75eb-4c61-bbe7-d738c3d8a4c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("935e6661-75eb-4c61-bbe7-d738c3d8a4c2")) {                    Plotly.newPlot(                        "935e6661-75eb-4c61-bbe7-d738c3d8a4c2",                        [{"hovertemplate": "date=%{x}<br>adj_close=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["2020-12-08T00:00:00+00:00", "2020-12-09T00:00:00+00:00", "2020-12-10T00:00:00+00:00", "2020-12-11T00:00:00+00:00", "2020-12-14T00:00:00+00:00", "2020-12-15T00:00:00+00:00", "2020-12-16T00:00:00+00:00", "2020-12-17T00:00:00+00:00", "2020-12-1
# ...
